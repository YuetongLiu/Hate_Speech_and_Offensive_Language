# %%
import pandas as pd
import numpy as np
import nltk
import string
import re

# %% [markdown]
# # Load Raw Data

# %%
df=pd.read_csv("../data/labeled_data.csv")
df.drop(df.columns[[0]], axis=1,inplace=True)
print(df.iloc[:5,:])
print(df.shape)
# Out:
#    count  hate_speech  offensive_language  neither  class  \
# 0      3            0                   0        3      2
# 1      3            0                   3        0      1
# 2      3            0                   3        0      1
# 3      3            0                   2        1      1
# 4      6            0                   6        0      1
#
#                                                tweet
# 0  !!! RT @mayasolovely: As a woman you shouldn't...
# 1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...
# (24783, 6)

# %% [markdown]
# # Data Pre-processing

# %%
stopwords = nltk.corpus.stopwords.words("english")
txt=df.iloc[:,5]
tweet=txt.copy(deep=True)
#tweet=pd.DataFrame(tweet)
#transform to lower case
tweet=tweet.str.lower()
#remove punctuation
remove = str.maketrans('','',string.punctuation) 
tweet = tweet.str.translate(remove)
#word tokenize and remove stopwords
#remove digit and excessive whitespace
for i in range(tweet.shape[0]):
    text=tweet[i]
    text1=''.join([ch+" " for ch in text.split() if ch not in ' 123456789'])
    text2=''.join([word+" " for word in text1.split() if word not in stopwords])
    tweet[i]=text2
info=re.compile('[0-9|rt]')
tweet=tweet.apply(lambda x: info.sub('',x))
print(tweet[:5])
# Out:
# 0     mayasolovely woman shouldn complain cleaning ...
# 1     mleew boy das coldyga dwn bad cuffin da hoe s...
# 2     ukindofband dawg  sbabylife eve fuck bich sa ...
# 3                  cgandeson vivabased look like anny
# 4     shenikaobes shi hea migh ue migh fake bich ol...
# Name: tweet, dtype: object

# %%
"""
do more process of replacing:
    1) urls
    2) lots of whitespace with one instance
    3) mentions
"""
def preprocess(text_string):
    space_pattern = '\s+'
    giant_url_regex = ('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|'
        '[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    mention_regex = '@[\w\-]+'
    parsed_text = re.sub(space_pattern, ' ', text_string)
    parsed_text = re.sub(giant_url_regex, '', parsed_text)
    parsed_text = re.sub(mention_regex, '', parsed_text)
    #parsed_text = parsed_text.code("utf-8", errors='ignore')
    return parsed_text
for i in range(tweet.shape[0]):
    text=tweet[i]
    text1=preprocess(text)
    tweet[i]=text1
print(tweet[:5])
# Out:
# 0     mayasolovely woman shouldn complain cleaning ...
# 1     mleew boy das coldyga dwn bad cuffin da hoe s...
# 2     ukindofband dawg sbabylife eve fuck bich sa c...
# 3                  cgandeson vivabased look like anny
# 4     shenikaobes shi hea migh ue migh fake bich ol...
# Name: tweet, dtype: object

# %% [markdown]
# # average len of tweet

# %%
#average len of tweet
import matplotlib.pyplot as plt
avg=0
num=[]
x=[x for x in range(24783)]
for n in range(tweet.shape[0]):
    avg+=len(tweet[n])
    num.append(len(tweet[n]))
avg=avg/(tweet.shape[0])
plt.bar(x,num)
plt.show()
print(avg)
# Out:
# 50.66953153371263

# %%
word=[]
for i in range(tweet.shape[0]):
    w=tweet[i].replace('\n','').rstrip()
    w1=w.split(" ")
    word.append(w1)
def flatten(seq):
    s=str(seq).replace('[', '').replace(']', '') 
    return [eval(x) for x in s.split(',') if x.strip()] 
word=[x for x in flatten(word)]
word=[x for x in word if x!='']
len(word)
# Out:
# 212672

# %%
word
# Out:
# ['mayasolovely',
#  'woman',
#  'shouldn',
#  'complain',
#  'cleaning',
#  'house',
#  'amp',
#  'man',
#  'always',
#  'ake',
#  'ash',
#  'mleew',
#  'boy',
#  'das',
#  'coldyga',
#  'dwn',
#  'bad',
#  'cuffin',
#  'da',
#  'hoe',
#  's',
#  'place',
#  'ukindofband',
#  'dawg',
#  'sbabylife',
#  'eve',
#  'fuck',
#  'bich',
#  'sa',
#  'cy',
#  'confused',
#  'shi',
#  'cgandeson',
#  'vivabased',
#  'look',
#  'like',
#  'anny',
#  'shenikaobes',
#  'shi',
#  'hea',
#  'migh',
#  'ue',
#  'migh',
#  'fake',
#  'bich',
#  'old',
#  'ya',
#  'madisonx',
#  'shi',
#  'blows',
#  'meclaim',
#  'faihful',
#  'somebody',
#  'sill',
#  'fucking',
#  'hoes',
#  'bighedays',
#  'si',
#  'hae',
#  'anohe',
#  'bich',
#  'go',
#  'much',
#  'shi',
#  'going',
#  'selfiequeenbi',
#  'cause',
#  'im',
#  'ied',
#  'big',
#  'biches',
#  'coming',
#  'us',
#  'skinny',
#  'gils',
#  'amp',
#  'migh',
#  'ge',
#  'ya',
#  'bich',
#  'back',
#  'amp',
#  'has',
#  'hyhmixx',
#  'hobbies',
#  'include',
#  'fighing',
#  'maiam',
#  'bich',
#  'keeks',
#  'bich',
#  'cuves',
#  'eveyone',
#  'lol',
#  'walked',
#  'convesaion',
#  'like',
#  'smh',
#  'muda',
#  'gang',
#  'bich',
#  'gang',
#  'land',
#  'hoes',
#  'smoke',
#  'loses',
#  'yea',
#  'go',
#  'ig',
#  'bad',
#  'biches',
#  'hing',
#  'like',
#  'bich',
#  'ge',
#  'bich',
#  'nigga',
#  'miss',
#  'bich',
#  'plz',
#  'whaeve',
#  'bich',
#  'love',
#  'biches',
#  'ge',
#  'cu',
#  'eveyday',
#  'b',
#  'black',
#  'bole',
#  'amp',
#  'bad',
#  'bich',
#  'boke',
#  'bich',
#  'can',
#  'ell',
#  'nohing',
#  'cancel',
#  'bich',
#  'like',
#  'nino',
#  'can',
#  'see',
#  'hoes',
#  'won',
#  'change',
#  'fuck',
#  'bich',
#  'don',
#  'even',
#  'suck',
#  'dick',
#  'kemi',
#  'videos',
#  'bou',
#  'fuck',
#  'ig',
#  'go',
#  'ya',
#  'bich',
#  'ip',
#  'oeing',
#  'hadwood',
#  'floos',
#  'hpcocouwqlq',
#  'pussy',
#  'lips',
#  'like',
#  'heaven',
#  'doos',
#  'hoe',
#  'hiing',
#  'me',
#  'pussy',
#  'ocean',
#  'd',
#  'gave',
#  'pussy',
#  'pill',
#  'need',
#  'ippy',
#  'bich',
#  'fuck',
#  'hennessy',
#  'spend',
#  'money',
#  'wan',
#  'bich',
#  'business',
#  'x',
#  'old',
#  'bich',
#  'new',
#  'bich',
#  'pussy',
#  'wee',
#  'id',
#  'say',
#  'im',
#  'back',
#  'old',
#  'old',
#  'biches',
#  'would',
#  'ge',
#  'excied',
#  'ain',
#  'bou',
#  'mude',
#  'game',
#  'pussy',
#  'nigga',
#  'shu',
#  'youe',
#  'oes',
#  'ain',
#  'done',
#  'pussy',
#  'sinks',
#  'im',
#  'done',
#  'bie',
#  'biches',
#  'wap',
#  'angy',
#  'bid',
#  'hees',
#  'app',
#  'ya',
#  'bich',
#  'ain',
#  'nohing',
#  'cu',
#  'bich',
#  'jus',
#  'mee',
#  'son',
#  'ya',
#  'mane',
#  'ass',
#  'biches',
#  'shos',
#  'lames',
#  'cying',
#  'hoes',
#  'has',
#  'eas',
#  'clown',
#  'like',
#  'snoop',
#  'said',
#  'don',
#  'love',
#  'hoes',
#  'momma',
#  'said',
#  'pussy',
#  'cas',
#  'inside',
#  'doghouse',
#  'haed',
#  'hoes',
#  'favoie',
#  'mw',
#  'sevenone',
#  'hpcobmdsvmcc',
#  'nice',
#  'gils',
#  'bad',
#  'make',
#  'ge',
#  'naughy',
#  'bad',
#  'yello',
#  'hoe',
#  'eal',
#  'nice',
#  'body',
#  'souh',
#  'chick',
#  'like',
#  'em',
#  'eal',
#  'hick',
#  'hpcobzdlkfu',
#  'pimps',
#  'pimps',
#  'hoes',
#  'fuue',
#  'voice',
#  'pos',
#  'picue',
#  'pussy',
#  'ge',
#  'likes',
#  'pussy',
#  'poweful',
#  'dug',
#  'happyhumpday',
#  'hpcojsymibb',
#  'quick',
#  'piece',
#  'pussy',
#  'call',
#  'dive',
#  'unning',
#  'ound',
#  'like',
#  'band',
#  'new',
#  'pussy',
#  'has',
#  'bou',
#  'ge',
#  'fucked',
#  'biches',
#  'even',
#  'wos',
#  'heyll',
#  'send',
#  'guys',
#  'hoes',
#  'like',
#  'niggas',
#  'spend',
#  'money',
#  'alk',
#  'bou',
#  'don',
#  'us',
#  'niggas',
#  'biches',
#  'yall',
#  'niggas',
#  'b',
#  'cuffing',
#  'hoes',
#  'cause',
#  'yall',
#  'ain',
#  'neve',
#  'biches',
#  'dodge',
#  'bulle',
#  'daealkha',
#  'da',
#  'biches',
#  'cu',
#  'pegnan',
#  'bound',
#  'hank',
#  'god',
#  'young',
#  'pill',
#  'chambelain',
#  'biches',
#  'love',
#  'music',
#  'vandalsavage',
#  'eanna',
#  'ump',
#  'pobably',
#  'cleane',
#  'wie',
#  'hoes',
#  'dahomiefuzz',
#  'gay',
#  'niggas',
#  'couldn',
#  'wai',
#  'ac',
#  'like',
#  'biches',
#  'onigh',
#  'hepaadox',
#  'ima',
#  'seal',
#  'ca',
#  'n',
#  'eplace',
#  'pibull',
#  'sbabylife',
#  'hepaadox',
#  'bich',
#  'amp',
#  'hes',
#  'gone',
#  'always',
#  'hoe',
#  'son',
#  'bich',
#  'ook',
#  'ic',
#  'acs',
#  'like',
#  'movie',
#  'wanna',
#  'ge',
#  'money',
#  'fuck',
#  'model',
#  'biches',
#  'ussell',
#  'simmons',
#  'seniopobs',
#  'pobably',
#  'wouldn',
#  'mind',
#  'school',
#  'much',
#  'didn',
#  'deal',
#  'bich',
#  'ass',
#  'eaches',
#  'ewee',
#  'axdemey',
#  'im',
#  'fucking',
#  'fag',
#  'said',
#  'aizzleindacu',
#  'females',
#  'hink',
#  'daing',
#  'pussy',
#  'cue',
#  'hpcovxbjggsz',
#  'suff',
#  'make',
#  'pussy',
#  'addicedguys',
#  'simplyaddicedoguys',
#  'hpcojlhizmf',
#  'woof',
#  'woof',
#  'ho',
#  'scally',
#  'lad',
#  'adoebellaaa',
#  'ya',
#  'eve',
#  'asked',
#  'bich',
#  'biches',
#  'kanye',
#  'voice',
#  'yes',
#  'adoezoey',
#  'u',
#  'gone',
#  'bing',
#  'u',
#  'side',
#  'bich',
#  'game',
#  'know',
#  'ya',
#  'gf',
#  'fiends',
#  'swea',
#  'allaboumanfee',
#  'hpcogzupfumev',
#  'woof',
#  'woof',
#  'ho',
#  'soles',
#  'allyhaaaaa',
#  'lemmie',
#  'ea',
#  'oeo',
#  'amp',
#  'dishes',
#  'one',
#  'oeo',
#  'lol',
#  'almighywayne',
#  'jesandaswishe',
#  'gook',
#  'bich',
#  'fuck',
#  'u',
#  'hpcopxmganc',
#  'maybe',
#  'youll',
#  'ge',
#  'bee',
#  'hpcopevwfqs',
#  'almighywayne',
#  'fuck',
#  'ed',
#  'malone',
#  'man',
#  'bich',
#  'ass',
#  'niggah',
#  'could',
#  'please',
#  'use',
#  'complee',
#  'senences',
#  'aizonasfines',
#  'eggplan',
#  'emoji',
#  'doey',
#  'say',
#  'looked',
#  'like',
#  'sceam',
#  'lmao',
#  'auowoid',
#  'hennessey',
#  'venom',
#  'g',
#  'hpcoiegmnkaj',
#  'has',
#  'one',
#  'sexy',
#  'bich',
#  'bossbychh',
#  'seh',
#  'pussy',
#  'wee',
#  'showe',
#  'cuainahmesehwenessllmao',
#  'bohen',
#  'eaglesnaion',
#  'evey',
#  'eagles',
#  'need',
#  'see',
#  'pic',
#  'posed',
#  'bich',
#  'said',
#  'acis',
#  'shi',
#  'bvsedchink',
#  'yo',
#  'fuck',
#  'skaeboading',
#  'yall',
#  'wood',
#  'pushing',
#  'faggos',
#  'man',
#  'ball',
#  'life',
#  'hpcovbczphm',
#  'amjemiebenn',
#  'babyanimalpics',
#  'baby',
#  'monkey',
#  'bahime',
#  'hpcokpwadlf',
#  'awwwwe',
#  'soooo',
#  'adoable',
#  'baylaagoabody',
#  'ain',
#  'shi',
#  'damn',
#  'skippy',
#  'lol',
#  'beeasyjizzy',
#  'u',
#  'eve',
#  'kill',
#  'an',
#  'sidewalk',
#  'hink',
#  'damn',
#  'nigga',
#  'way',
#  'ge',
#  'pussyno',
#  'bs',
#  'mus',
#  'b',
#  'gchance',
#  'beenbasedb',
#  'kudabazyy',
#  'hpcoluubglyu',
#  'ings',
#  'mvps',
#  'biches',
#  'lol',
#  'beenflynsolo',
#  'ppl',
#  'alk',
#  'bad',
#  'gheohood',
#  'kid',
#  'gowing',
#  'nigga',
#  'funnnnnnn',
#  'bespoadvice',
#  'facs',
#  'aoosaoo',
#  'hpcozwnbhpdze',
#  'hes',
#  'pussy',
#  'aooing',
#  'nipples',
#  'bill',
#  'nelayden',
#  'biches',
#  'waning',
#  'ac',
#  'like',
#  'niggas',
#  'bad',
#  'shi',
#  'ain',
#  'cueeeee',
#  'niggas',
#  'ac',
#  'like',
#  'biches',
#  'bichjones',
#  'ge',
#  'woshiping',
#  'bich',
#  'hpcocejcjou',
#  'woof',
#  'woof',
#  'blackchiquiia',
#  'wow',
#  'hamanpalme',
#  'im',
#  'los',
#  'bucheek',
#  'piecings',
#  'hpcoynguyouq',
#  'yeah',
#  'shes',
#  'hoe',
#  'blacknedjade',
#  'ok',
#  'sis',
#  'shed',
#  'ahe',
#  'boke',
#  'bich',
#  'shugs',
#  'shell',
#  'ell',
#  'woks',
#  'blackmanide',
#  'whalelookyhee',
#  'howdydowdy',
#  'quee',
#  'gaywad',
#  'bokenpiecesmsc',
#  'isnoadam',
#  'faggo',
#  'ead',
#  'wees',
#  'da',
#  'k',
#  'wasn',
#  'even',
#  'funny',
#  'lol',
#  'bosconfessions',
#  'bich',
#  'ungaeful',
#  'hpcoebgwbx',
#  'f',
#  'lulwhoe',
#  'cashandboobies',
#  'kidnapped',
#  'yo',
#  'bich',
#  'cbbaby',
#  'whiehunduh',
#  'alsaabsss',
#  'hes',
#  'beane',
#  'smh',
#  'ell',
#  'hes',
#  'mexican',
#  'ccobey',
#  'aydanmccoy',
#  'happy',
#  'bihday',
#  'nigs',
#  'hanks',
#  'yo',
#  'chlldhooduine',
#  'u',
#  'eache',
#  'ells',
#  'u',
#  'u',
#  'homewok',
#  'hpscokkvawij',
#  'bich',
#  'need',
#  'go',
#  'caelang',
#  'edham',
#  'caelang',
#  'nigga',
#  'eaing',
#  'hoe',
#  'lol',
#  'hell',
#  'yea',
#  'lol',
#  'john',
#  'paul',
#  'nigga',
#  'said',
#  'john',
#  'paul',
#  'hpcoosipbkph',
#  'canifuckonah',
#  'would',
#  'yall',
#  'lil',
#  'ugly',
#  'bald',
#  'headed',
#  'biches',
#  'sop',
#  'making',
#  'makeup',
#  'amp',
#  'weave',
#  'caelessone',
#  'leafs',
#  'bee',
#  'win',
#  'damn',
#  'game',
#  'go',
#  'io',
#  'shi',
#  'ealychismas',
#  'bee',
#  'sa',
#  'looing',
#  'nig',
#  'causeweeguys',
#  'going',
#  'back',
#  'school',
#  'sucks',
#  'dick',
#  'hoes',
#  'aend',
#  'causeweeguys',
#  'way',
#  'fuck',
#  'yo',
#  'bich',
#  'hpcojze',
#  'yea',
#  'old',
#  'celeynichole',
#  'whiehunduh',
#  'come',
#  'neve',
#  'bing',
#  'food',
#  'don',
#  'ca',
#  'ead',
#  'chadmfvebeck',
#  'ichnow',
#  'doesn',
#  'show',
#  'hella',
#  'inde',
#  'hoes',
#  'im',
#  'fiend',
#  'anymoe',
#  'chill',
#  'bough',
#  'like',
#  'like',
#  'pople',
#  'chandlepasons',
#  'bou',
#  'cowboys',
#  'shuup',
#  'pussy',
#  'clicquosuave',
#  'lmaooooooooooo',
#  'nigga',
#  'killznuhcae',
#  'hpcoaanpsujmyi',
#  'lbich',
#  'wan',
#  'likes',
#  'depessing',
#  'shifoh',
#  'coleycee',
#  'lilaeii',
#  'gil',
#  'know',
#  'spiing',
#  'g',
#  'shi',
#  'amp',
#  'going',
#  'lbvsbich',
#  'plz',
#  'coleycee',
#  'le',
#  'make',
#  'couple',
#  'wees',
#  'cuzzo',
#  'page',
#  'won',
#  'ge',
#  'wie',
#  'jaillmao',
#  'bich',
#  'don',
#  'ick',
#  'comedyposs',
#  'halem',
#  'shake',
#  'excuse',
#  'go',
#  'full',
#  'ead',
#  'seconds',
#  'comedyuh',
#  'amen',
#  'miley',
#  'hpcopkbfyxokay',
#  'don',
#  'need',
#  'ac',
#  'like',
#  'hoe',
#  'bc',
#  'shes',
#  'emoionally',
#  'damaged',
#  'foh',
#  'coybandz',
#  'one',
#  'loyal',
#  'female',
#  'wayyyyy',
#  'bee',
#  'hoes',
#  'idc',
#  'chedys',
#  'pussy',
#  'licking',
#  'pussy',
#  'meow',
#  'meow',
#  'sopwhiepeople',
#  'hpscokeegdcjsk',
#  'dbabholloway',
#  'check',
#  'h',
#  'man',
#  'cowboysnaion',
#  'even',
#  'faggo',
#  'ny',
#  'fans',
#  'sands',
#  'dgobicks',
#  'happen',
#  'vixen',
#  'en',
#  'biches',
#  'go',
#  'an',
#  'hew',
#  'side',
#  'like',
#  'foohill',
#  'bich',
#  'daedavidavie',
#  'whiehunduh',
#  'im',
#  'bich',
#  'okay',
#  'nudes',
#  'pa',
#  'wow',
#  'devilgimz',
#  'vigxas',
#  'youe',
#  'fucking',
#  'gay',
#  'blacklised',
#  'hoe',
#  'holding',
#  'ehgodclan',
#  'anyway',
#  'hpcoxuccwoemn',
#  'diamondloudkush',
#  'fuck',
#  'wong',
#  'biches',
#  'nobody',
#  'knows',
#  'dieich',
#  'yall',
#  'shu',
#  'upp',
#  'make',
#  'bich',
#  'dionaiish',
#  'hae',
#  'im',
#  'pegnan',
#  'ype',
#  'bich',
#  'doyouq',
#  'go',
#  'biches',
#  'dm',
#  'don',
#  'eve',
#  'eadem',
#  'op',
#  'domwoldpeace',
#  'baseball',
#  'season',
#  'win',
#  'yankees',
#  'love',
#  'saed',
#  'dommoneek',
#  'lile',
#  'supid',
#  'bich',
#  'don',
#  'fuck',
#  'yoooooouuuu',
#  'deadheadai',
#  'eally',
#  'asked',
#  'dead',
#  'ass',
#  'seious',
#  'ho',
#  'could',
#  'say',
#  'bich',
#  'whee',
#  'lol',
#  'dundebail',
#  'im',
#  'ealy',
#  'bid',
#  'im',
#  'nigh',
#  'owl',
#  'im',
#  'wise',
#  'woms',
#  'edgapixa',
#  'ovedosing',
#  'heavy',
#  'dugs',
#  'doesn',
#  'sound',
#  'bad',
#  'onigh',
#  'pussy',
#  'shi',
#  'evey',
#  'day',
#  'elgillo',
#  'pi',
#  'bulls',
#  'phoogaphed',
#  'lovely',
#  'faiy',
#  'ale',
#  'ceaues',
#  'hpcoqsmoolh',
#  'faiy',
#  'ale',
#  'ceaues',
#  'feociousghos',
#  'snamebavo',
#  'aw',
#  'fag',
#  'don',
#  'wee',
#  'aw',
#  'lol',
#  'flokid',
#  ...]

# %%
#create the input data for word2vec
for i in range(len(tweet)):
    doc=tweet[i]
    doc=doc.split(" ")
    doc=[x for x in doc if x!='']
    tweet[i]=doc
tweet[:5]
# Out:
# 0    [mayasolovely, woman, shouldn, complain, clean...
# 1    [mleew, boy, das, coldyga, dwn, bad, cuffin, d...
# 2    [ukindofband, dawg, sbabylife, eve, fuck, bich...
# 3             [cgandeson, vivabased, look, like, anny]
# 4    [shenikaobes, shi, hea, migh, ue, migh, fake, ...
# Name: tweet, dtype: object

# %%
#word2vec by skip-gram
from gensim.models.word2vec import Word2Vec
import warnings
warnings.filterwarnings(action='ignore', category=UserWarning, module='gensim')

model = Word2Vec(size=100, workers=5,sg=1)  #dimension is 200, consider 5 words, using skip-gram
model.build_vocab(tweet)
model.train(tweet,total_examples = model.corpus_count,epochs = 5)
# Out:
# (1257482, 7168555)

# %%
import warnings
warnings.filterwarnings("ignore")
word_vec=[]
#average each word vector to get the vector of a single tweet
for i in range(len(tweet)):
    sum1=0
    for w in tweet[i]:
        try:
            sum1+=model[w]
        except:
            continue
    avg=sum1/(len(tweet[i]))
    avg=list(avg)
    word_vec.append(avg)
word_vec[:5]
# Out:
# [[-0.089646965,
#   -0.024854371,
#   0.11568685,
#   0.06351444,
#   -0.1498932,
#   -0.017533232,
#   -0.056381032,
#   -0.05305469,
#   0.009896989,
#   0.04620107,
#   0.013437165,
#   -0.0483266,
#   -0.039056476,
#   0.23948024,
#   -0.029048888,
#   -0.02947286,
#   0.06060563,
#   -0.048472986,
#   0.05645546,
#   0.027367512,
#   -0.003862183,
#   -0.06549984,
#   0.059421167,
#   -0.055169266,
#   -0.14167263,
#   -0.06528592,
#   -0.050525714,
#   0.055287268,
#   0.0031239833,
#   0.14713052,
#   -0.13828735,
#   -0.11251025,
#   0.06815335,
#   -0.07838824,
#   0.06480203,
#   -0.13261506,
#   0.0804047,
#   -0.032810263,
#   -0.021515409,
#   -0.007853796,
#   -0.012507181,
#   0.033271056,
#   0.08774809,
#   0.17570369,
#   0.08431547,
#   -0.0032909785,
#   -0.05292795,
#   -0.011255134,
#   -0.007460096,
#   0.0032989148,
#   0.037632525,
#   -0.08555657,
#   0.029332774,
#   0.010602289,
#   0.016884793,
#   0.01717177,
#   0.060620103,
#   0.10452439,
#   0.034024216,
#   0.019931523,
#   -0.07703666,
#   -0.06862958,
#   -0.04021663,
#   0.037553735,
#   -0.033132613,
#   -0.03133919,
#   -0.042226456,
#   -0.015179571,
#   0.0067029987,
#   0.007507707,
#   0.043146607,
#   0.061032142,
#   -0.044259425,
#   -0.022832727,
#   -0.017953025,
#   0.024474869,
#   -0.016289132,
#   0.05474131,
#   -0.003865883,
#   0.02139181,
#   -0.0080835745,
#   -0.009578937,
#   -0.023744175,
#   0.025868755,
#   -0.04016919,
#   0.03285347,
#   -0.13667686,
#   -0.03366411,
#   0.024652489,
#   0.1067063,
#   0.06424265,
#   0.035975575,
#   0.048072048,
#   -0.1015944,
#   0.042607874,
#   0.020032547,
#   0.06699371,
#   -0.04635497,
#   0.006164761,
#   0.13388078],
#  [-0.08670322,
#   -0.021880833,
#   0.12436834,
#   0.06594911,
#   -0.14399157,
#   -0.0006469143,
#   -0.057807457,
#   -0.052407708,
#   0.0044536814,
#   0.05866305,
#   0.00020606659,
#   -0.04876523,
#   -0.048324477,
#   0.23297845,
#   -0.023429304,
#   -0.023098307,
#   0.049767513,
#   -0.0395685,
#   0.056584187,
#   0.037141923,
#   -0.0031404984,
#   -0.074981675,
#   0.057173222,
#   -0.059331656,
#   -0.14038616,
#   -0.07286009,
#   -0.039352085,
#   0.049726825,
#   0.0032455253,
#   0.14680156,
#   -0.1389754,
#   -0.11042112,
#   0.065376006,
#   -0.078574635,
#   0.07321983,
#   -0.13489182,
#   0.073771454,
#   0.026077205,
#   0.04886748,
#   0.072929405,
#   -0.045764636,
#   -0.03163624,
#   -0.015570587,
#   0.02106572,
#   -0.018455952,
#   0.06743868,
#   0.0039415364,
#   0.02685927,
#   -0.010445025,
#   -0.013091927,
#   -0.03778484,
#   0.041756287,
#   -0.03411336,
#   0.026324496,
#   -0.1531096,
#   -0.052324466,
#   0.023306213,
#   0.101471014,
#   0.07633016,
#   0.030065626,
#   0.05447346,
#   -0.10222971,
#   0.038076267,
#   0.02666446,
#   0.06801346,
#   -0.03784984,
#   4.7395373e-05,
#   0.116692975]]

# %%
len(word_vec)
# Out:
# 24783

# %%
word_vec_array=np.array(word_vec)
word_vec_l=np.reshape(word_vec_array[0],(1,100))
for i in range(len(tweet)):
    array=np.reshape(word_vec_array[i],(1,100))
    word_vec_l=np.r_[word_vec_l,array]
word_vec_l
# Out:
# array([[-0.08964697, -0.02485437,  0.11568685, ..., -0.04635497,
#          0.00616476,  0.13388078],
#        [-0.08964697, -0.02485437,  0.11568685, ..., -0.04635497,
#          0.00616476,  0.13388078],
#        [-0.08670322, -0.02188083,  0.12436834, ..., -0.05034522,
#          0.00217686,  0.12128469],
#        ...,
#        [-0.07866132, -0.02891641,  0.12444007, ..., -0.04342868,
#         -0.00215617,  0.12979881],
#        [-0.07604176, -0.01985686,  0.12876543, ..., -0.04982484,
#          0.00636654,  0.11683249],
#        [-0.07143672, -0.02488943,  0.11918682, ..., -0.04287231,
#          0.00539322,  0.11859816]], dtype=float32)

# %%
word_vec_lt=word_vec_l
word_vec_lt=np.delete(word_vec_lt,0,0)
word_vec_lt.shape
# Out:
# (24783, 100)

# %%
#save this array as csv
import csv
f = open('D:\jhu_ds\project\word2vec_skip.csv', 'w')
a = csv.writer(f)
a.writerows(word_vec_lt)
f.close()

# %%
np.savetxt('D:\jhu_ds\project\word2vec_skip1.csv', word_vec_lt, delimiter = ',')

# %%
# LDA

# %%
#LDA 
# construct dic for LDA 
from gensim import corpora, models
dictionary = corpora.Dictionary(tweet)
corpus = [dictionary.doc2bow(words) for words in tweet]
# lda model, num_topics is the number of topic
lda = models.ldamodel.LdaModel(corpus=corpus, id2word=dictionary, num_topics=3)
# print 5 words for each topic 
for topic in lda.print_topics(num_words=5):
    print(topic)
# topic infer
lda_infer= lda.inference(corpus)
print(lda.inference(corpus))
# Out:
# (0, '0.076*"bich" + 0.015*"biches" + 0.014*"like" + 0.013*"u" + 0.013*"ass"')
# (1, '0.024*"hoes" + 0.019*"pussy" + 0.012*"ash" + 0.010*"go" + 0.010*"biches"')
# (2, '0.019*"biches" + 0.011*"like" + 0.008*"fucking" + 0.008*"hoe" + 0.006*"go"')
# (array([[ 6.1542068 ,  5.450454  ,  0.39533967],
#        [ 5.051908  ,  6.5762186 ,  0.37187317],
#        [10.270213  ,  0.38614166,  0.34364396],
#        ...,
#        [10.134589  ,  0.50511676,  0.36029354],
#        [ 6.263499  ,  0.35410953,  0.3823925 ],
#        [ 1.429044  ,  3.1991944 , 10.371762  ]], dtype=float32), None)

# %%
print(lda_infer[0].shape)
# Out:
# (24783, 3)

# %%
lda_infer_array=lda_infer[0]
